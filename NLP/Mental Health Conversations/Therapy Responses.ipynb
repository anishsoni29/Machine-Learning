# %% [markdown]
# ## Installing the dependencies

# %%
# %env TOKENIZERS_PARALLELISM = true
# Out:
# env: TOKENIZERS_PARALLELISM=true

# %%
# !pip install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 774.1 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.6 MB/s eta 0:00:00a 0:00:01
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125925 sha256=6c542f89f794ea7df296b70094e43880ef0a12fe75057c7cc35779072f725881
#   Stored in directory: /Users/anishsoni/Library/Caches/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
import pandas as pd
df = pd.read_csv('/Users/anishsoni/Desktop/Machine-Learning/NLP/Mental Health Conversations/train.csv')

# %%
df.head()
# Out:
#                                              Context  \
# 0  I'm going through some things with my feelings...
# 1  I'm going through some things with my feelings...
# 2  I'm going through some things with my feelings...
# 3  I'm going through some things with my feelings...
# 4  I'm going through some things with my feelings...
#
#                                             Response
# 0  If everyone thinks you're worthless, then mayb...
# 1  Hello, and thank you for your question and see...
# 2  First thing I'd suggest is getting the sleep y...
# 3  Therapy is essential for those that are feelin...
# 4  I first want to let you know that you are not ...

# %% [markdown]
# ## Cleaning the dataset

# %%
viz = df.dropna(subset = 'Response').drop(columns = 'Context').drop_duplicates(ignore_index = True)
viz
#going with responses only because they have more linguistic diversity
# Out:
#                                                Response
# 0     If everyone thinks you're worthless, then mayb...
# 1     Hello, and thank you for your question and see...
# 2     First thing I'd suggest is getting the sleep y...
# 3     Therapy is essential for those that are feelin...
# 4     I first want to let you know that you are not ...
# ...                                                 ...
# 2474  Being in this position is tough. If seeking an...
# 2475  It sounds like you are on the right track. Rec...
# 2476  Hello.It sounds like you are really concerned ...
# 2477  Hi.  This is an excellent question !   I think...
# 2478                           hmm this is a tough one!
#
# [2479 rows x 1 columns]

# %%
viz.head()
# Out:
#                                             Response
# 0  If everyone thinks you're worthless, then mayb...
# 1  Hello, and thank you for your question and see...
# 2  First thing I'd suggest is getting the sleep y...
# 3  Therapy is essential for those that are feelin...
# 4  I first want to let you know that you are not ...

# %%
viz.nunique()
# Out:
# Response    2479
# dtype: int64

# %% [markdown]
# ## Importing the necessary libraries

# %%
# !pip install wordcloud
from matplotlib.pyplot import subplots,axis,imshow
from wordcloud import WordCloud, STOPWORDS
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 kB 1.7 MB/s eta 0:00:00a 0:00:01
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
FRACTION = 1.0
subplots(figsize=(12,12))
text = ' '.join(viz.sample(frac = FRACTION, random_state = 2023)['Response'].values.tolist())
imshow(X= WordCloud(random_state = 2023, height = 1200, width=1200, stopwords = STOPWORDS,).generate(text=text),)
axis('off')
# Out:
# (-0.5, 1199.5, 1199.5, -0.5)
